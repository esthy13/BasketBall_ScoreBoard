# %% [markdown]
# <a href="https://colab.research.google.com/github/esthy13/BasketBall_ScoreBoard/blob/main/01_small_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I have only small data
# **Data augmentation**
# - rotation
# - crop
# - shifting
#
# --> making transformations to the data, to make the model more robust
